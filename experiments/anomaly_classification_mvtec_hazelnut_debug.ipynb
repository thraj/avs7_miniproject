# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Dataset, random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from tqdm import tqdm
import wandb
from PIL import Image

# %%
# Initialize Weights & Biases (wandb)
wandb.init(project="agco-anomaly-classification", entity="sameerhashmi1995")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sameerhashmi1995. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/home/sameerhashmi36/Documents/AVS7/ipcv_mini_project_avs7/wandb/run-20241029_003356-iimanknm</code>
# Syncing run <strong><a href='https://wandb.ai/sameerhashmi1995/agco-anomaly-classification/runs/iimanknm' target="_blank">dainty-totem-22</a></strong> to <a href='https://wandb.ai/sameerhashmi1995/agco-anomaly-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sameerhashmi1995/agco-anomaly-classification' target="_blank">https://wandb.ai/sameerhashmi1995/agco-anomaly-classification</a>
#  View run at <a href='https://wandb.ai/sameerhashmi1995/agco-anomaly-classification/runs/iimanknm' target="_blank">https://wandb.ai/sameerhashmi1995/agco-anomaly-classification/runs/iimanknm</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/sameerhashmi1995/agco-anomaly-classification/runs/iimanknm?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
class CustomImageDataset(Dataset):
    """
    Custom dataset class for loading images from root directory.
    It reads images from 'good' and 'synthetic_anomalous' folders and assigns labels accordingly.
    """
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        self.labels = []
        self.classes = {'good': 0, 'synthetic_anomalous': 1}

        for label in os.listdir(root_dir):
            label_path = os.path.join(root_dir, label)
            if os.path.isdir(label_path):
                for img_file in os.listdir(label_path):
                    img_path = os.path.join(label_path, img_file)
                    self.data.append(img_path)
                    self.labels.append(self.classes[label])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = self.data[idx]
        
        # Use PIL to open the image and convert to RGB to ensure 3 channels
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        label = self.labels[idx]
        return image, label

# %%
from collections import defaultdict

# Initialize the dataset
root_dir = "./datasets/mvtec_with_synthetic_anomalous/hazelnut"
transform = None 
dataset = CustomImageDataset(root_dir=root_dir, transform=transform)

# Dictionary to store shapes for each class
shapes_by_class = defaultdict(list)

# Iterate through the dataset and record the shapes
for image, label in dataset:
    image = np.array(image)
    shapes_by_class[label].append(image.shape)

# Print the shapes of images for each class
for label, shapes in shapes_by_class.items():
    print(f"Class {label}:")
    for i, shape in enumerate(shapes[:]):  # Display up to the first 5 shapes for brevity
        print(f"  Image {i} shape: {shape}")
    print(f"  Total images in class {label}: {len(shapes)}\n")
# Out:
# Class 1:
#   Image 0 shape: (256, 256, 3)
#   Image 1 shape: (256, 256, 3)
#   Image 2 shape: (256, 256, 3)
#   Image 3 shape: (256, 256, 3)
#   Image 4 shape: (256, 256, 3)
#   Image 5 shape: (256, 256, 3)
#   Image 6 shape: (256, 256, 3)
#   Image 7 shape: (256, 256, 3)
#   Image 8 shape: (256, 256, 3)
#   Image 9 shape: (256, 256, 3)
#   Image 10 shape: (256, 256, 3)
#   Image 11 shape: (256, 256, 3)
#   Image 12 shape: (256, 256, 3)
#   Image 13 shape: (256, 256, 3)
#   Image 14 shape: (256, 256, 3)
#   Image 15 shape: (256, 256, 3)
#   Image 16 shape: (256, 256, 3)
#   Image 17 shape: (256, 256, 3)
#   Image 18 shape: (256, 256, 3)
#   Image 19 shape: (256, 256, 3)
#   Image 20 shape: (256, 256, 3)
#   Image 21 shape: (256, 256, 3)
#   Image 22 shape: (256, 256, 3)
#   Image 23 shape: (256, 256, 3)
#   Image 24 shape: (256, 256, 3)
#   Image 25 shape: (256, 256, 3)
#   Image 26 shape: (256, 256, 3)
#   Image 27 shape: (256, 256, 3)
#   Image 28 shape: (256, 256, 3)
#   Image 29 shape: (256, 256, 3)
#   Image 30 shape: (256, 256, 3)
#   Image 31 shape: (256, 256, 3)
#   Image 32 shape: (256, 256, 3)
#   Image 33 shape: (256, 256, 3)
#   Image 34 shape: (256, 256, 3)
#   Image 35 shape: (256, 256, 3)
#   Image 36 shape: (256, 256, 3)
#   Image 37 shape: (256, 256, 3)
#   Image 38 shape: (256, 256, 3)
#   Image 39 shape: (256, 256, 3)
#   Image 40 shape: (256, 256, 3)
#   Image 41 shape: (256, 256, 3)
#   Image 42 shape: (256, 256, 3)
#   Image 43 shape: (256, 256, 3)
#   Image 44 shape: (256, 256, 3)
#   Image 45 shape: (256, 256, 3)
#   Image 46 shape: (256, 256, 3)
#   Image 47 shape: (256, 256, 3)
#   Image 48 shape: (256, 256, 3)
#   Image 49 shape: (256, 256, 3)
#   Image 50 shape: (256, 256, 3)
#   Image 51 shape: (256, 256, 3)
#   Image 52 shape: (256, 256, 3)
#   Image 53 shape: (256, 256, 3)
#   Image 54 shape: (256, 256, 3)
#   Image 55 shape: (256, 256, 3)
#   Image 56 shape: (256, 256, 3)
#   Image 57 shape: (256, 256, 3)
#   Image 58 shape: (256, 256, 3)
#   Image 59 shape: (256, 256, 3)
#   Image 60 shape: (256, 256, 3)
#   Image 61 shape: (256, 256, 3)
#   Image 62 shape: (256, 256, 3)
#   Image 63 shape: (256, 256, 3)
#   Image 64 shape: (256, 256, 3)
#   Image 65 shape: (256, 256, 3)
#   Image 66 shape: (256, 256, 3)
#   Image 67 shape: (256, 256, 3)
#   Image 68 shape: (256, 256, 3)
#   Image 69 shape: (256, 256, 3)
#   Image 70 shape: (256, 256, 3)
#   Image 71 shape: (256, 256, 3)
#   Image 72 shape: (256, 256, 3)
#   Image 73 shape: (256, 256, 3)
#   Image 74 shape: (256, 256, 3)
#   Image 75 shape: (256, 256, 3)
#   Image 76 shape: (256, 256, 3)
#   Image 77 shape: (256, 256, 3)
#   Image 78 shape: (256, 256, 3)
#   Image 79 shape: (256, 256, 3)
#   Image 80 shape: (256, 256, 3)
#   Image 81 shape: (256, 256, 3)
#   Image 82 shape: (256, 256, 3)
#   Image 83 shape: (256, 256, 3)
#   Image 84 shape: (256, 256, 3)
#   Image 85 shape: (256, 256, 3)
#   Image 86 shape: (256, 256, 3)
#   Image 87 shape: (256, 256, 3)
#   Image 88 shape: (256, 256, 3)
#   Image 89 shape: (256, 256, 3)
#   Image 90 shape: (256, 256, 3)
#   Image 91 shape: (256, 256, 3)
#   Image 92 shape: (256, 256, 3)
#   Image 93 shape: (256, 256, 3)
#   Image 94 shape: (256, 256, 3)
#   Image 95 shape: (256, 256, 3)
#   Image 96 shape: (256, 256, 3)
#   Image 97 shape: (256, 256, 3)
#   Image 98 shape: (256, 256, 3)
#   Image 99 shape: (256, 256, 3)
#   Image 100 shape: (256, 256, 3)
#   Image 101 shape: (256, 256, 3)
#   Image 102 shape: (256, 256, 3)
#   Image 103 shape: (256, 256, 3)
#   Image 104 shape: (256, 256, 3)
#   Image 105 shape: (256, 256, 3)
#   Image 106 shape: (256, 256, 3)
#   Image 107 shape: (256, 256, 3)
#   Image 108 shape: (256, 256, 3)
#   Image 109 shape: (256, 256, 3)
#   Image 110 shape: (256, 256, 3)
#   Image 111 shape: (256, 256, 3)
#   Image 112 shape: (256, 256, 3)
#   Image 113 shape: (256, 256, 3)
#   Image 114 shape: (256, 256, 3)
#   Image 115 shape: (256, 256, 3)
#   Image 116 shape: (256, 256, 3)
#   Image 117 shape: (256, 256, 3)
#   Image 118 shape: (256, 256, 3)
#   Image 119 shape: (256, 256, 3)
#   Image 120 shape: (256, 256, 3)
#   Image 121 shape: (256, 256, 3)
#   Image 122 shape: (256, 256, 3)
#   Image 123 shape: (256, 256, 3)
#   Image 124 shape: (256, 256, 3)
#   Image 125 shape: (256, 256, 3)
#   Image 126 shape: (256, 256, 3)
#   Image 127 shape: (256, 256, 3)
#   Image 128 shape: (256, 256, 3)
#   Image 129 shape: (256, 256, 3)
#   Image 130 shape: (256, 256, 3)
#   Image 131 shape: (256, 256, 3)
#   Image 132 shape: (256, 256, 3)
#   Image 133 shape: (256, 256, 3)
#   Image 134 shape: (256, 256, 3)
#   Image 135 shape: (256, 256, 3)
#   Image 136 shape: (256, 256, 3)
#   Image 137 shape: (256, 256, 3)
#   Image 138 shape: (256, 256, 3)
#   Image 139 shape: (256, 256, 3)
#   Image 140 shape: (256, 256, 3)
#   Image 141 shape: (256, 256, 3)
#   Image 142 shape: (256, 256, 3)
#   Image 143 shape: (256, 256, 3)
#   Image 144 shape: (256, 256, 3)
#   Image 145 shape: (256, 256, 3)
#   Image 146 shape: (256, 256, 3)
#   Image 147 shape: (256, 256, 3)
#   Image 148 shape: (256, 256, 3)
#   Image 149 shape: (256, 256, 3)
#   Image 150 shape: (256, 256, 3)
#   Image 151 shape: (256, 256, 3)
#   Image 152 shape: (256, 256, 3)
#   Image 153 shape: (256, 256, 3)
#   Image 154 shape: (256, 256, 3)
#   Image 155 shape: (256, 256, 3)
#   Image 156 shape: (256, 256, 3)
#   Image 157 shape: (256, 256, 3)
#   Image 158 shape: (256, 256, 3)
#   Image 159 shape: (256, 256, 3)
#   Image 160 shape: (256, 256, 3)
#   Image 161 shape: (256, 256, 3)
#   Image 162 shape: (256, 256, 3)
#   Image 163 shape: (256, 256, 3)
#   Image 164 shape: (256, 256, 3)
#   Image 165 shape: (256, 256, 3)
#   Image 166 shape: (256, 256, 3)
#   Image 167 shape: (256, 256, 3)
#   Image 168 shape: (256, 256, 3)
#   Image 169 shape: (256, 256, 3)
#   Image 170 shape: (256, 256, 3)
#   Image 171 shape: (256, 256, 3)
#   Image 172 shape: (256, 256, 3)
#   Image 173 shape: (256, 256, 3)
#   Image 174 shape: (256, 256, 3)
#   Image 175 shape: (256, 256, 3)
#   Image 176 shape: (256, 256, 3)
#   Image 177 shape: (256, 256, 3)
#   Image 178 shape: (256, 256, 3)
#   Image 179 shape: (256, 256, 3)
#   Image 180 shape: (256, 256, 3)
#   Image 181 shape: (256, 256, 3)
#   Image 182 shape: (256, 256, 3)
#   Image 183 shape: (256, 256, 3)
#   Image 184 shape: (256, 256, 3)
#   Image 185 shape: (256, 256, 3)
#   Image 186 shape: (256, 256, 3)
#   Image 187 shape: (256, 256, 3)
#   Image 188 shape: (256, 256, 3)
#   Image 189 shape: (256, 256, 3)
#   Image 190 shape: (256, 256, 3)
#   Image 191 shape: (256, 256, 3)
#   Image 192 shape: (256, 256, 3)
#   Image 193 shape: (256, 256, 3)
#   Image 194 shape: (256, 256, 3)
#   Image 195 shape: (256, 256, 3)
#   Image 196 shape: (256, 256, 3)
#   Image 197 shape: (256, 256, 3)
#   Image 198 shape: (256, 256, 3)
#   Image 199 shape: (256, 256, 3)
#   Image 200 shape: (256, 256, 3)
#   Image 201 shape: (256, 256, 3)
#   Image 202 shape: (256, 256, 3)
#   Image 203 shape: (256, 256, 3)
#   Image 204 shape: (256, 256, 3)
#   Image 205 shape: (256, 256, 3)
#   Image 206 shape: (256, 256, 3)
#   Image 207 shape: (256, 256, 3)
#   Image 208 shape: (256, 256, 3)
#   Image 209 shape: (256, 256, 3)
#   Image 210 shape: (256, 256, 3)
#   Image 211 shape: (256, 256, 3)
#   Image 212 shape: (256, 256, 3)
#   Image 213 shape: (256, 256, 3)
#   Image 214 shape: (256, 256, 3)
#   Image 215 shape: (256, 256, 3)
#   Image 216 shape: (256, 256, 3)
#   Image 217 shape: (256, 256, 3)
#   Image 218 shape: (256, 256, 3)
#   Image 219 shape: (256, 256, 3)
#   Image 220 shape: (256, 256, 3)
#   Image 221 shape: (256, 256, 3)
#   Image 222 shape: (256, 256, 3)
#   Image 223 shape: (256, 256, 3)
#   Image 224 shape: (256, 256, 3)
#   Image 225 shape: (256, 256, 3)
#   Image 226 shape: (256, 256, 3)
#   Image 227 shape: (256, 256, 3)
#   Image 228 shape: (256, 256, 3)
#   Image 229 shape: (256, 256, 3)
#   Image 230 shape: (256, 256, 3)
#   Image 231 shape: (256, 256, 3)
#   Image 232 shape: (256, 256, 3)
#   Image 233 shape: (256, 256, 3)
#   Image 234 shape: (256, 256, 3)
#   Image 235 shape: (256, 256, 3)
#   Image 236 shape: (256, 256, 3)
#   Image 237 shape: (256, 256, 3)
#   Image 238 shape: (256, 256, 3)
#   Image 239 shape: (256, 256, 3)
#   Image 240 shape: (256, 256, 3)
#   Image 241 shape: (256, 256, 3)
#   Image 242 shape: (256, 256, 3)
#   Image 243 shape: (256, 256, 3)
#   Image 244 shape: (256, 256, 3)
#   Image 245 shape: (256, 256, 3)
#   Image 246 shape: (256, 256, 3)
#   Image 247 shape: (256, 256, 3)
#   Image 248 shape: (256, 256, 3)
#   Image 249 shape: (256, 256, 3)
#   Image 250 shape: (256, 256, 3)
#   Image 251 shape: (256, 256, 3)
#   Image 252 shape: (256, 256, 3)
#   Image 253 shape: (256, 256, 3)
#   Image 254 shape: (256, 256, 3)
#   Image 255 shape: (256, 256, 3)
#   Image 256 shape: (256, 256, 3)
#   Image 257 shape: (256, 256, 3)
#   Image 258 shape: (256, 256, 3)
#   Image 259 shape: (256, 256, 3)
#   Image 260 shape: (256, 256, 3)
#   Image 261 shape: (256, 256, 3)
#   Image 262 shape: (256, 256, 3)
#   Image 263 shape: (256, 256, 3)
#   Image 264 shape: (256, 256, 3)
#   Image 265 shape: (256, 256, 3)
#   Image 266 shape: (256, 256, 3)
#   Image 267 shape: (256, 256, 3)
#   Image 268 shape: (256, 256, 3)
#   Image 269 shape: (256, 256, 3)
#   Image 270 shape: (256, 256, 3)
#   Image 271 shape: (256, 256, 3)
#   Image 272 shape: (256, 256, 3)
#   Image 273 shape: (256, 256, 3)
#   Image 274 shape: (256, 256, 3)
#   Image 275 shape: (256, 256, 3)
#   Image 276 shape: (256, 256, 3)
#   Image 277 shape: (256, 256, 3)
#   Image 278 shape: (256, 256, 3)
#   Image 279 shape: (256, 256, 3)
#   Image 280 shape: (256, 256, 3)
#   Image 281 shape: (256, 256, 3)
#   Image 282 shape: (256, 256, 3)
#   Image 283 shape: (256, 256, 3)
#   Image 284 shape: (256, 256, 3)
#   Image 285 shape: (256, 256, 3)
#   Image 286 shape: (256, 256, 3)
#   Image 287 shape: (256, 256, 3)
#   Image 288 shape: (256, 256, 3)
#   Image 289 shape: (256, 256, 3)
#   Image 290 shape: (256, 256, 3)
#   Image 291 shape: (256, 256, 3)
#   Image 292 shape: (256, 256, 3)
#   Image 293 shape: (256, 256, 3)
#   Image 294 shape: (256, 256, 3)
#   Image 295 shape: (256, 256, 3)
#   Image 296 shape: (256, 256, 3)
#   Image 297 shape: (256, 256, 3)
#   Image 298 shape: (256, 256, 3)
#   Image 299 shape: (256, 256, 3)
#   Image 300 shape: (256, 256, 3)
#   Image 301 shape: (256, 256, 3)
#   Image 302 shape: (256, 256, 3)
#   Image 303 shape: (256, 256, 3)
#   Image 304 shape: (256, 256, 3)
#   Image 305 shape: (256, 256, 3)
#   Image 306 shape: (256, 256, 3)
#   Image 307 shape: (256, 256, 3)
#   Image 308 shape: (256, 256, 3)
#   Image 309 shape: (256, 256, 3)
#   Image 310 shape: (256, 256, 3)
#   Image 311 shape: (256, 256, 3)
#   Image 312 shape: (256, 256, 3)
#   Image 313 shape: (256, 256, 3)
#   Image 314 shape: (256, 256, 3)
#   Image 315 shape: (256, 256, 3)
#   Image 316 shape: (256, 256, 3)
#   Image 317 shape: (256, 256, 3)
#   Image 318 shape: (256, 256, 3)
#   Image 319 shape: (256, 256, 3)
#   Image 320 shape: (256, 256, 3)
#   Image 321 shape: (256, 256, 3)
#   Image 322 shape: (256, 256, 3)
#   Image 323 shape: (256, 256, 3)
#   Image 324 shape: (256, 256, 3)
#   Image 325 shape: (256, 256, 3)
#   Image 326 shape: (256, 256, 3)
#   Image 327 shape: (256, 256, 3)
#   Image 328 shape: (256, 256, 3)
#   Image 329 shape: (256, 256, 3)
#   Image 330 shape: (256, 256, 3)
#   Image 331 shape: (256, 256, 3)
#   Image 332 shape: (256, 256, 3)
#   Image 333 shape: (256, 256, 3)
#   Image 334 shape: (256, 256, 3)
#   Image 335 shape: (256, 256, 3)
#   Image 336 shape: (256, 256, 3)
#   Image 337 shape: (256, 256, 3)
#   Image 338 shape: (256, 256, 3)
#   Image 339 shape: (256, 256, 3)
#   Image 340 shape: (256, 256, 3)
#   Image 341 shape: (256, 256, 3)
#   Image 342 shape: (256, 256, 3)
#   Image 343 shape: (256, 256, 3)
#   Image 344 shape: (256, 256, 3)
#   Image 345 shape: (256, 256, 3)
#   Image 346 shape: (256, 256, 3)
#   Image 347 shape: (256, 256, 3)
#   Image 348 shape: (256, 256, 3)
#   Image 349 shape: (256, 256, 3)
#   Image 350 shape: (256, 256, 3)
#   Image 351 shape: (256, 256, 3)
#   Image 352 shape: (256, 256, 3)
#   Image 353 shape: (256, 256, 3)
#   Image 354 shape: (256, 256, 3)
#   Image 355 shape: (256, 256, 3)
#   Image 356 shape: (256, 256, 3)
#   Image 357 shape: (256, 256, 3)
#   Image 358 shape: (256, 256, 3)
#   Image 359 shape: (256, 256, 3)
#   Image 360 shape: (256, 256, 3)
#   Image 361 shape: (256, 256, 3)
#   Image 362 shape: (256, 256, 3)
#   Image 363 shape: (256, 256, 3)
#   Image 364 shape: (256, 256, 3)
#   Image 365 shape: (256, 256, 3)
#   Image 366 shape: (256, 256, 3)
#   Image 367 shape: (256, 256, 3)
#   Image 368 shape: (256, 256, 3)
#   Image 369 shape: (256, 256, 3)
#   Image 370 shape: (256, 256, 3)
#   Image 371 shape: (256, 256, 3)
#   Image 372 shape: (256, 256, 3)
#   Image 373 shape: (256, 256, 3)
#   Image 374 shape: (256, 256, 3)
#   Image 375 shape: (256, 256, 3)
#   Image 376 shape: (256, 256, 3)
#   Image 377 shape: (256, 256, 3)
#   Image 378 shape: (256, 256, 3)
#   Image 379 shape: (256, 256, 3)
#   Image 380 shape: (256, 256, 3)
#   Image 381 shape: (256, 256, 3)
#   Image 382 shape: (256, 256, 3)
#   Image 383 shape: (256, 256, 3)
#   Image 384 shape: (256, 256, 3)
#   Image 385 shape: (256, 256, 3)
#   Image 386 shape: (256, 256, 3)
#   Image 387 shape: (256, 256, 3)
#   Image 388 shape: (256, 256, 3)
#   Total images in class 1: 389
#
# Class 0:
#   Image 0 shape: (1024, 1024, 3)
#   Image 1 shape: (1024, 1024, 3)
#   Image 2 shape: (1024, 1024, 3)
#   Image 3 shape: (1024, 1024, 3)
#   Image 4 shape: (1024, 1024, 3)
#   Image 5 shape: (1024, 1024, 3)
#   Image 6 shape: (1024, 1024, 3)
#   Image 7 shape: (1024, 1024, 3)
#   Image 8 shape: (1024, 1024, 3)
#   Image 9 shape: (1024, 1024, 3)
#   Image 10 shape: (1024, 1024, 3)
#   Image 11 shape: (1024, 1024, 3)
#   Image 12 shape: (1024, 1024, 3)
#   Image 13 shape: (1024, 1024, 3)
#   Image 14 shape: (1024, 1024, 3)
#   Image 15 shape: (1024, 1024, 3)
#   Image 16 shape: (1024, 1024, 3)
#   Image 17 shape: (1024, 1024, 3)
#   Image 18 shape: (1024, 1024, 3)
#   Image 19 shape: (1024, 1024, 3)
#   Image 20 shape: (1024, 1024, 3)
#   Image 21 shape: (1024, 1024, 3)
#   Image 22 shape: (1024, 1024, 3)
#   Image 23 shape: (1024, 1024, 3)
#   Image 24 shape: (1024, 1024, 3)
#   Image 25 shape: (1024, 1024, 3)
#   Image 26 shape: (1024, 1024, 3)
#   Image 27 shape: (1024, 1024, 3)
#   Image 28 shape: (1024, 1024, 3)
#   Image 29 shape: (1024, 1024, 3)
#   Image 30 shape: (1024, 1024, 3)
#   Image 31 shape: (1024, 1024, 3)
#   Image 32 shape: (1024, 1024, 3)
#   Image 33 shape: (1024, 1024, 3)
#   Image 34 shape: (1024, 1024, 3)
#   Image 35 shape: (1024, 1024, 3)
#   Image 36 shape: (1024, 1024, 3)
#   Image 37 shape: (1024, 1024, 3)
#   Image 38 shape: (1024, 1024, 3)
#   Image 39 shape: (1024, 1024, 3)
#   Image 40 shape: (1024, 1024, 3)
#   Image 41 shape: (1024, 1024, 3)
#   Image 42 shape: (1024, 1024, 3)
#   Image 43 shape: (1024, 1024, 3)
#   Image 44 shape: (1024, 1024, 3)
#   Image 45 shape: (1024, 1024, 3)
#   Image 46 shape: (1024, 1024, 3)
#   Image 47 shape: (1024, 1024, 3)
#   Image 48 shape: (1024, 1024, 3)
#   Image 49 shape: (1024, 1024, 3)
#   Image 50 shape: (1024, 1024, 3)
#   Image 51 shape: (1024, 1024, 3)
#   Image 52 shape: (1024, 1024, 3)
#   Image 53 shape: (1024, 1024, 3)
#   Image 54 shape: (1024, 1024, 3)
#   Image 55 shape: (1024, 1024, 3)
#   Image 56 shape: (1024, 1024, 3)
#   Image 57 shape: (1024, 1024, 3)
#   Image 58 shape: (1024, 1024, 3)
#   Image 59 shape: (1024, 1024, 3)
#   Image 60 shape: (1024, 1024, 3)
#   Image 61 shape: (1024, 1024, 3)
#   Image 62 shape: (1024, 1024, 3)
#   Image 63 shape: (1024, 1024, 3)
#   Image 64 shape: (1024, 1024, 3)
#   Image 65 shape: (1024, 1024, 3)
#   Image 66 shape: (1024, 1024, 3)
#   Image 67 shape: (1024, 1024, 3)
#   Image 68 shape: (1024, 1024, 3)
#   Image 69 shape: (1024, 1024, 3)
#   Image 70 shape: (1024, 1024, 3)
#   Image 71 shape: (1024, 1024, 3)
#   Image 72 shape: (1024, 1024, 3)
#   Image 73 shape: (1024, 1024, 3)
#   Image 74 shape: (1024, 1024, 3)
#   Image 75 shape: (1024, 1024, 3)
#   Image 76 shape: (1024, 1024, 3)
#   Image 77 shape: (1024, 1024, 3)
#   Image 78 shape: (1024, 1024, 3)
#   Image 79 shape: (1024, 1024, 3)
#   Image 80 shape: (1024, 1024, 3)
#   Image 81 shape: (1024, 1024, 3)
#   Image 82 shape: (1024, 1024, 3)
#   Image 83 shape: (1024, 1024, 3)
#   Image 84 shape: (1024, 1024, 3)
#   Image 85 shape: (1024, 1024, 3)
#   Image 86 shape: (1024, 1024, 3)
#   Image 87 shape: (1024, 1024, 3)
#   Image 88 shape: (1024, 1024, 3)
#   Image 89 shape: (1024, 1024, 3)
#   Image 90 shape: (1024, 1024, 3)
#   Image 91 shape: (1024, 1024, 3)
#   Image 92 shape: (1024, 1024, 3)
#   Image 93 shape: (1024, 1024, 3)
#   Image 94 shape: (1024, 1024, 3)
#   Image 95 shape: (1024, 1024, 3)
#   Image 96 shape: (1024, 1024, 3)
#   Image 97 shape: (1024, 1024, 3)
#   Image 98 shape: (1024, 1024, 3)
#   Image 99 shape: (1024, 1024, 3)
#   Image 100 shape: (1024, 1024, 3)
#   Image 101 shape: (1024, 1024, 3)
#   Image 102 shape: (1024, 1024, 3)
#   Image 103 shape: (1024, 1024, 3)
#   Image 104 shape: (1024, 1024, 3)
#   Image 105 shape: (1024, 1024, 3)
#   Image 106 shape: (1024, 1024, 3)
#   Image 107 shape: (1024, 1024, 3)
#   Image 108 shape: (1024, 1024, 3)
#   Image 109 shape: (1024, 1024, 3)
#   Image 110 shape: (1024, 1024, 3)
#   Image 111 shape: (1024, 1024, 3)
#   Image 112 shape: (1024, 1024, 3)
#   Image 113 shape: (1024, 1024, 3)
#   Image 114 shape: (1024, 1024, 3)
#   Image 115 shape: (1024, 1024, 3)
#   Image 116 shape: (1024, 1024, 3)
#   Image 117 shape: (1024, 1024, 3)
#   Image 118 shape: (1024, 1024, 3)
#   Image 119 shape: (1024, 1024, 3)
#   Image 120 shape: (1024, 1024, 3)
#   Image 121 shape: (1024, 1024, 3)
#   Image 122 shape: (1024, 1024, 3)
#   Image 123 shape: (1024, 1024, 3)
#   Image 124 shape: (1024, 1024, 3)
#   Image 125 shape: (1024, 1024, 3)
#   Image 126 shape: (1024, 1024, 3)
#   Image 127 shape: (1024, 1024, 3)
#   Image 128 shape: (1024, 1024, 3)
#   Image 129 shape: (1024, 1024, 3)
#   Image 130 shape: (1024, 1024, 3)
#   Image 131 shape: (1024, 1024, 3)
#   Image 132 shape: (1024, 1024, 3)
#   Image 133 shape: (1024, 1024, 3)
#   Image 134 shape: (1024, 1024, 3)
#   Image 135 shape: (1024, 1024, 3)
#   Image 136 shape: (1024, 1024, 3)
#   Image 137 shape: (1024, 1024, 3)
#   Image 138 shape: (1024, 1024, 3)
#   Image 139 shape: (1024, 1024, 3)
#   Image 140 shape: (1024, 1024, 3)
#   Image 141 shape: (1024, 1024, 3)
#   Image 142 shape: (1024, 1024, 3)
#   Image 143 shape: (1024, 1024, 3)
#   Image 144 shape: (1024, 1024, 3)
#   Image 145 shape: (1024, 1024, 3)
#   Image 146 shape: (1024, 1024, 3)
#   Image 147 shape: (1024, 1024, 3)
#   Image 148 shape: (1024, 1024, 3)
#   Image 149 shape: (1024, 1024, 3)
#   Image 150 shape: (1024, 1024, 3)
#   Image 151 shape: (1024, 1024, 3)
#   Image 152 shape: (1024, 1024, 3)
#   Image 153 shape: (1024, 1024, 3)
#   Image 154 shape: (1024, 1024, 3)
#   Image 155 shape: (1024, 1024, 3)
#   Image 156 shape: (1024, 1024, 3)
#   Image 157 shape: (1024, 1024, 3)
#   Image 158 shape: (1024, 1024, 3)
#   Image 159 shape: (1024, 1024, 3)
#   Image 160 shape: (1024, 1024, 3)
#   Image 161 shape: (1024, 1024, 3)
#   Image 162 shape: (1024, 1024, 3)
#   Image 163 shape: (1024, 1024, 3)
#   Image 164 shape: (1024, 1024, 3)
#   Image 165 shape: (1024, 1024, 3)
#   Image 166 shape: (1024, 1024, 3)
#   Image 167 shape: (1024, 1024, 3)
#   Image 168 shape: (1024, 1024, 3)
#   Image 169 shape: (1024, 1024, 3)
#   Image 170 shape: (1024, 1024, 3)
#   Image 171 shape: (1024, 1024, 3)
#   Image 172 shape: (1024, 1024, 3)
#   Image 173 shape: (1024, 1024, 3)
#   Image 174 shape: (1024, 1024, 3)
#   Image 175 shape: (1024, 1024, 3)
#   Image 176 shape: (1024, 1024, 3)
#   Image 177 shape: (1024, 1024, 3)
#   Image 178 shape: (1024, 1024, 3)
#   Image 179 shape: (1024, 1024, 3)
#   Image 180 shape: (1024, 1024, 3)
#   Image 181 shape: (1024, 1024, 3)
#   Image 182 shape: (1024, 1024, 3)
#   Image 183 shape: (1024, 1024, 3)
#   Image 184 shape: (1024, 1024, 3)
#   Image 185 shape: (1024, 1024, 3)
#   Image 186 shape: (1024, 1024, 3)
#   Image 187 shape: (1024, 1024, 3)
#   Image 188 shape: (1024, 1024, 3)
#   Image 189 shape: (1024, 1024, 3)
#   Image 190 shape: (1024, 1024, 3)
#   Image 191 shape: (1024, 1024, 3)
#   Image 192 shape: (1024, 1024, 3)
#   Image 193 shape: (1024, 1024, 3)
#   Image 194 shape: (1024, 1024, 3)
#   Image 195 shape: (1024, 1024, 3)
#   Image 196 shape: (1024, 1024, 3)
#   Image 197 shape: (1024, 1024, 3)
#   Image 198 shape: (1024, 1024, 3)
#   Image 199 shape: (1024, 1024, 3)
#   Image 200 shape: (1024, 1024, 3)
#   Image 201 shape: (1024, 1024, 3)
#   Image 202 shape: (1024, 1024, 3)
#   Image 203 shape: (1024, 1024, 3)
#   Image 204 shape: (1024, 1024, 3)
#   Image 205 shape: (1024, 1024, 3)
#   Image 206 shape: (1024, 1024, 3)
#   Image 207 shape: (1024, 1024, 3)
#   Image 208 shape: (1024, 1024, 3)
#   Image 209 shape: (1024, 1024, 3)
#   Image 210 shape: (1024, 1024, 3)
#   Image 211 shape: (1024, 1024, 3)
#   Image 212 shape: (1024, 1024, 3)
#   Image 213 shape: (1024, 1024, 3)
#   Image 214 shape: (1024, 1024, 3)
#   Image 215 shape: (1024, 1024, 3)
#   Image 216 shape: (1024, 1024, 3)
#   Image 217 shape: (1024, 1024, 3)
#   Image 218 shape: (1024, 1024, 3)
#   Image 219 shape: (1024, 1024, 3)
#   Image 220 shape: (1024, 1024, 3)
#   Image 221 shape: (1024, 1024, 3)
#   Image 222 shape: (1024, 1024, 3)
#   Image 223 shape: (1024, 1024, 3)
#   Image 224 shape: (1024, 1024, 3)
#   Image 225 shape: (1024, 1024, 3)
#   Image 226 shape: (1024, 1024, 3)
#   Image 227 shape: (1024, 1024, 3)
#   Image 228 shape: (1024, 1024, 3)
#   Image 229 shape: (1024, 1024, 3)
#   Image 230 shape: (1024, 1024, 3)
#   Image 231 shape: (1024, 1024, 3)
#   Image 232 shape: (1024, 1024, 3)
#   Image 233 shape: (1024, 1024, 3)
#   Image 234 shape: (1024, 1024, 3)
#   Image 235 shape: (1024, 1024, 3)
#   Image 236 shape: (1024, 1024, 3)
#   Image 237 shape: (1024, 1024, 3)
#   Image 238 shape: (1024, 1024, 3)
#   Image 239 shape: (1024, 1024, 3)
#   Image 240 shape: (1024, 1024, 3)
#   Image 241 shape: (1024, 1024, 3)
#   Image 242 shape: (1024, 1024, 3)
#   Image 243 shape: (1024, 1024, 3)
#   Image 244 shape: (1024, 1024, 3)
#   Image 245 shape: (1024, 1024, 3)
#   Image 246 shape: (1024, 1024, 3)
#   Image 247 shape: (1024, 1024, 3)
#   Image 248 shape: (1024, 1024, 3)
#   Image 249 shape: (1024, 1024, 3)
#   Image 250 shape: (1024, 1024, 3)
#   Image 251 shape: (1024, 1024, 3)
#   Image 252 shape: (1024, 1024, 3)
#   Image 253 shape: (1024, 1024, 3)
#   Image 254 shape: (1024, 1024, 3)
#   Image 255 shape: (1024, 1024, 3)
#   Image 256 shape: (1024, 1024, 3)
#   Image 257 shape: (1024, 1024, 3)
#   Image 258 shape: (1024, 1024, 3)
#   Image 259 shape: (1024, 1024, 3)
#   Image 260 shape: (1024, 1024, 3)
#   Image 261 shape: (1024, 1024, 3)
#   Image 262 shape: (1024, 1024, 3)
#   Image 263 shape: (1024, 1024, 3)
#   Image 264 shape: (1024, 1024, 3)
#   Image 265 shape: (1024, 1024, 3)
#   Image 266 shape: (1024, 1024, 3)
#   Image 267 shape: (1024, 1024, 3)
#   Image 268 shape: (1024, 1024, 3)
#   Image 269 shape: (1024, 1024, 3)
#   Image 270 shape: (1024, 1024, 3)
#   Image 271 shape: (1024, 1024, 3)
#   Image 272 shape: (1024, 1024, 3)
#   Image 273 shape: (1024, 1024, 3)
#   Image 274 shape: (1024, 1024, 3)
#   Image 275 shape: (1024, 1024, 3)
#   Image 276 shape: (1024, 1024, 3)
#   Image 277 shape: (1024, 1024, 3)
#   Image 278 shape: (1024, 1024, 3)
#   Image 279 shape: (1024, 1024, 3)
#   Image 280 shape: (1024, 1024, 3)
#   Image 281 shape: (1024, 1024, 3)
#   Image 282 shape: (1024, 1024, 3)
#   Image 283 shape: (1024, 1024, 3)
#   Image 284 shape: (1024, 1024, 3)
#   Image 285 shape: (1024, 1024, 3)
#   Image 286 shape: (1024, 1024, 3)
#   Image 287 shape: (1024, 1024, 3)
#   Image 288 shape: (1024, 1024, 3)
#   Image 289 shape: (1024, 1024, 3)
#   Image 290 shape: (1024, 1024, 3)
#   Image 291 shape: (1024, 1024, 3)
#   Image 292 shape: (1024, 1024, 3)
#   Image 293 shape: (1024, 1024, 3)
#   Image 294 shape: (1024, 1024, 3)
#   Image 295 shape: (1024, 1024, 3)
#   Image 296 shape: (1024, 1024, 3)
#   Image 297 shape: (1024, 1024, 3)
#   Image 298 shape: (1024, 1024, 3)
#   Image 299 shape: (1024, 1024, 3)
#   Image 300 shape: (1024, 1024, 3)
#   Image 301 shape: (1024, 1024, 3)
#   Image 302 shape: (1024, 1024, 3)
#   Image 303 shape: (1024, 1024, 3)
#   Image 304 shape: (1024, 1024, 3)
#   Image 305 shape: (1024, 1024, 3)
#   Image 306 shape: (1024, 1024, 3)
#   Image 307 shape: (1024, 1024, 3)
#   Image 308 shape: (1024, 1024, 3)
#   Image 309 shape: (1024, 1024, 3)
#   Image 310 shape: (1024, 1024, 3)
#   Image 311 shape: (1024, 1024, 3)
#   Image 312 shape: (1024, 1024, 3)
#   Image 313 shape: (1024, 1024, 3)
#   Image 314 shape: (1024, 1024, 3)
#   Image 315 shape: (1024, 1024, 3)
#   Image 316 shape: (1024, 1024, 3)
#   Image 317 shape: (1024, 1024, 3)
#   Image 318 shape: (1024, 1024, 3)
#   Image 319 shape: (1024, 1024, 3)
#   Image 320 shape: (1024, 1024, 3)
#   Image 321 shape: (1024, 1024, 3)
#   Image 322 shape: (1024, 1024, 3)
#   Image 323 shape: (1024, 1024, 3)
#   Image 324 shape: (1024, 1024, 3)
#   Image 325 shape: (1024, 1024, 3)
#   Image 326 shape: (1024, 1024, 3)
#   Image 327 shape: (1024, 1024, 3)
#   Image 328 shape: (1024, 1024, 3)
#   Image 329 shape: (1024, 1024, 3)
#   Image 330 shape: (1024, 1024, 3)
#   Image 331 shape: (1024, 1024, 3)
#   Image 332 shape: (1024, 1024, 3)
#   Image 333 shape: (1024, 1024, 3)
#   Image 334 shape: (1024, 1024, 3)
#   Image 335 shape: (1024, 1024, 3)
#   Image 336 shape: (1024, 1024, 3)
#   Image 337 shape: (1024, 1024, 3)
#   Image 338 shape: (1024, 1024, 3)
#   Image 339 shape: (1024, 1024, 3)
#   Image 340 shape: (1024, 1024, 3)
#   Image 341 shape: (1024, 1024, 3)
#   Image 342 shape: (1024, 1024, 3)
#   Image 343 shape: (1024, 1024, 3)
#   Image 344 shape: (1024, 1024, 3)
#   Image 345 shape: (1024, 1024, 3)
#   Image 346 shape: (1024, 1024, 3)
#   Image 347 shape: (1024, 1024, 3)
#   Image 348 shape: (1024, 1024, 3)
#   Image 349 shape: (1024, 1024, 3)
#   Image 350 shape: (1024, 1024, 3)
#   Image 351 shape: (1024, 1024, 3)
#   Image 352 shape: (1024, 1024, 3)
#   Image 353 shape: (1024, 1024, 3)
#   Image 354 shape: (1024, 1024, 3)
#   Image 355 shape: (1024, 1024, 3)
#   Image 356 shape: (1024, 1024, 3)
#   Image 357 shape: (1024, 1024, 3)
#   Image 358 shape: (1024, 1024, 3)
#   Image 359 shape: (1024, 1024, 3)
#   Image 360 shape: (1024, 1024, 3)
#   Image 361 shape: (1024, 1024, 3)
#   Image 362 shape: (1024, 1024, 3)
#   Image 363 shape: (1024, 1024, 3)
#   Image 364 shape: (1024, 1024, 3)
#   Image 365 shape: (1024, 1024, 3)
#   Image 366 shape: (1024, 1024, 3)
#   Image 367 shape: (1024, 1024, 3)
#   Image 368 shape: (1024, 1024, 3)
#   Image 369 shape: (1024, 1024, 3)
#   Image 370 shape: (1024, 1024, 3)
#   Image 371 shape: (1024, 1024, 3)
#   Image 372 shape: (1024, 1024, 3)
#   Image 373 shape: (1024, 1024, 3)
#   Image 374 shape: (1024, 1024, 3)
#   Image 375 shape: (1024, 1024, 3)
#   Image 376 shape: (1024, 1024, 3)
#   Image 377 shape: (1024, 1024, 3)
#   Image 378 shape: (1024, 1024, 3)
#   Image 379 shape: (1024, 1024, 3)
#   Image 380 shape: (1024, 1024, 3)
#   Image 381 shape: (1024, 1024, 3)
#   Image 382 shape: (1024, 1024, 3)
#   Image 383 shape: (1024, 1024, 3)
#   Image 384 shape: (1024, 1024, 3)
#   Image 385 shape: (1024, 1024, 3)
#   Image 386 shape: (1024, 1024, 3)
#   Image 387 shape: (1024, 1024, 3)
#   Image 388 shape: (1024, 1024, 3)
#   Image 389 shape: (1024, 1024, 3)
#   Image 390 shape: (1024, 1024, 3)
#   Total images in class 0: 391

# %%
transform = transforms.Compose([
    # transforms.Lambda(lambda x: x.convert('RGB') if x.mode != 'RGB' else x),
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    # transforms.Resize((224, 224))
])

# %%
dataset = CustomImageDataset(root_dir='./datasets/mvtec_with_synthetic_anomalous/hazelnut', transform=transform)

# %%
(dataset[0])
# Out:
# (tensor([[[0.1569, 0.1490, 0.1647,  ..., 0.1490, 0.1529, 0.1412],
#           [0.1451, 0.1490, 0.1490,  ..., 0.1451, 0.1451, 0.1451],
#           [0.1529, 0.1490, 0.1451,  ..., 0.1490, 0.1882, 0.1490],
#           ...,
#           [0.1451, 0.1412, 0.1412,  ..., 0.1412, 0.1333, 0.1333],
#           [0.1451, 0.1412, 0.1333,  ..., 0.1373, 0.1373, 0.1333],
#           [0.1255, 0.1412, 0.1373,  ..., 0.1412, 0.1373, 0.1412]],
#
#          [[0.1529, 0.1529, 0.1569,  ..., 0.1529, 0.1490, 0.1412],
#           [0.1529, 0.1490, 0.1490,  ..., 0.1412, 0.1529, 0.1412],
#           [0.1529, 0.1451, 0.1490,  ..., 0.1529, 0.1412, 0.1490],
#           ...,
#           [0.1412, 0.1451, 0.1412,  ..., 0.1373, 0.1333, 0.1451],
#           [0.1412, 0.1490, 0.1412,  ..., 0.1412, 0.1373, 0.1451],
#           [0.1529, 0.1412, 0.1373,  ..., 0.1451, 0.1451, 0.1451]],
#
#          [[0.1686, 0.1608, 0.1686,  ..., 0.1608, 0.1608, 0.1686],
#           [0.1765, 0.1647, 0.1725,  ..., 0.1529, 0.1647, 0.1647],
#           [0.1843, 0.1647, 0.1725,  ..., 0.1647, 0.1725, 0.1686],
#           ...,
#           [0.1686, 0.1608, 0.1647,  ..., 0.1569, 0.1529, 0.1608],
#           [0.1647, 0.1647, 0.1569,  ..., 0.1490, 0.1490, 0.1490],
#           [0.1529, 0.1608, 0.1608,  ..., 0.1569, 0.1569, 0.1490]]]),
#  1)

# %%
# Shuffle and split the dataset into train (65%), val (20%), and test (15%)
dataset_size = len(dataset)
train_size = int(0.65 * dataset_size)
val_size = int(0.20 * dataset_size)
test_size = dataset_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
good_count = sum(1 for label in dataset.labels if label == 0)
anomalous_count = len(dataset) - good_count

# %%
print(f'Good: {good_count}, Anomalous: {anomalous_count}')
print("Train dataset length: ",len(train_dataset), ", Val dataset length: ", len(val_dataset), ", Test dataset length: ", len(test_dataset))
# Out:
# Good: 391, Anomalous: 389
# Train dataset length:  507 , Val dataset length:  156 , Test dataset length:  117

# %%
# Visualizing data distribution

plt.bar(['Normal', 'Anomalous'], [good_count, anomalous_count])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Data Distribution')
plt.show()

# %%
# Calculating Mean and Standard Deviation
loader = DataLoader(dataset, batch_size=64, shuffle=False)
mean = torch.zeros(3).to('cuda')
std = torch.zeros(3).to('cuda')
nb_samples = 0

# %%
for data, _ in loader:
    data = data.to('cuda')
    batch_samples = data.size(0)
    data = data.view(batch_samples, data.size(1), -1)
    mean += data.mean(2).sum(0)
    std += data.std(2).sum(0)
    nb_samples += batch_samples

# %%
mean /= nb_samples
std /= nb_samples
print(f'Mean: {mean}, Std: {std}')
# Out:
# Mean: tensor([0.2404, 0.1771, 0.1716], device='cuda:0'), Std: tensor([0.1644, 0.0721, 0.0404], device='cuda:0')

# %%
plt.figure(figsize=(8, 4))
plt.bar(['Mean', 'Std'], [mean.mean().item(), std.mean().item()], color=['blue', 'orange'])
plt.xlabel('Statistics')
plt.ylabel('Value')
plt.title('Mean and Standard Deviation of Dataset')
plt.show()

# %%
# Visualizing some data

plt.figure(figsize=(20, 5))
for i in range(20):
    idx = torch.randint(0, len(dataset), (1,)).item()
    image, label = dataset[idx]
    plt.subplot(2, 10, i + 1)
    plt.imshow(image.permute(1, 2, 0))
    plt.title('Normal' if label == 0 else 'Anomalous')
    plt.axis('off')
plt.show()

# %%
class ResNet18(nn.Module):
    """
    Custom ResNet18 model for binary classification (Good vs Synthetic_anomalous).
    """
    def __init__(self):
        super(ResNet18, self).__init__()
        self.model = models.resnet18(pretrained=True)
        self.model.fc = nn.Linear(self.model.fc.in_features, 2)  # 2 classes (Good, Synthetic_anomalous)

    def forward(self, x):
        return self.model(x)

# %%
def train_model(model, criterion, optimizer, dataloader, device):
    """
    Function to train the model for one epoch.
    """
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in tqdm(dataloader, desc="Training", leave=False):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    epoch_loss = running_loss / len(dataloader.dataset)
    accuracy = 100 * correct / total
    wandb.log({"Train Loss": epoch_loss, "Train Accuracy": accuracy})
    return epoch_loss, accuracy

# %%
def validate_model(model, criterion, dataloader, device):
    """
    Function to validate the model after each epoch.
    """
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Validation", leave=False):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    epoch_loss = running_loss / len(dataloader.dataset)
    accuracy = 100 * correct / total
    wandb.log({"Validation Loss": epoch_loss, "Validation Accuracy": accuracy})
    return epoch_loss, accuracy

# %%
def test_model(model, dataloader, device):
    """
    Function to test the model on the test dataset.
    """
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Testing", leave=False):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    return y_true, y_pred

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
# Out:
# /home/sameerhashmi36/miniconda3/envs/test/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/sameerhashmi36/miniconda3/envs/test/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 10

best_val_acc = 0.0  # Initialize the best validation accuracy

for epoch in range(num_epochs):
    train_loss, train_acc = train_model(model, criterion, optimizer, train_loader, device)
    val_loss, val_acc = validate_model(model, criterion, val_loader, device)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')

    # Save model if validation accuracy improves
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), f'./mvtec_classification_weights/best_model.pth')
        print(f'Model saved at epoch {epoch+1} with validation accuracy: {val_acc:.2f}%')
# Out:
# Epoch [1/10], Train Loss: 0.0017, Train Acc: 100.00%, Val Loss: 3.4149, Val Acc: 60.90%
# Model saved at epoch 1 with validation accuracy: 60.90%
# Epoch [2/10], Train Loss: 0.0020, Train Acc: 100.00%, Val Loss: 3.3507, Val Acc: 60.90%
# Epoch [3/10], Train Loss: 0.0025, Train Acc: 99.80%, Val Loss: 0.0004, Val Acc: 100.00%
# Model saved at epoch 3 with validation accuracy: 100.00%
# Epoch [4/10], Train Loss: 0.0028, Train Acc: 99.80%, Val Loss: 0.0004, Val Acc: 100.00%
# Epoch [5/10], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0007, Val Acc: 100.00%
# Epoch [6/10], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0018, Val Acc: 100.00%
# Epoch [7/10], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Epoch [8/10], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Epoch [9/10], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Epoch [10/10], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%

# %%
y_true, y_pred = test_model(model, test_loader, device)

# %%
# Plotting Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomalous'], yticklabels=['Normal', 'Anomalous'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculating Precision, Recall, and F1 Score
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
# Out:
# Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000

# %%
# Logging metrics to wandb
wandb.log({"Precision": precision, "Recall": recall, "F1 Score": f1})

# %%
def visualize_examples(y_true, y_pred, dataset):
    """
    Function to visualize True Positives, True Negatives, False Positives, and False Negatives.
    """
    tp_indices = [i for i, (t, p) in enumerate(zip(y_true, y_pred)) if t == p == 1]
    tn_indices = [i for i, (t, p) in enumerate(zip(y_true, y_pred)) if t == p == 0]
    fp_indices = [i for i, (t, p) in enumerate(zip(y_true, y_pred)) if t == 0 and p == 1]
    fn_indices = [i for i, (t, p) in enumerate(zip(y_true, y_pred)) if t == 1 and p == 0]

    indices = {
        'True Positive': tp_indices,
        'True Negative': tn_indices,
        'False Positive': fp_indices,
        'False Negative': fn_indices
    }

    plt.figure(figsize=(20, 10))
    for i, (label, idx_list) in enumerate(indices.items()):
        if len(idx_list) > 0:
            idx = idx_list[torch.randint(0, len(idx_list), (1,)).item()]
            image, true_label = dataset[idx]
            predicted_label = 'good' if label in ['True Negative', 'False Negative'] else 'synthetic_anomalous'
            plt.subplot(2, 4, i + 1)
            plt.imshow(image.permute(1, 2, 0))
            plt.title(f'{label}\nTrue: {"good" if true_label == 0 else "synthetic_anomalous"} | Pred: {predicted_label}')
            plt.axis('off')
    plt.show()

# %%
visualize_examples(y_true, y_pred, test_dataset)
